# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
kieuhinh=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_data=kieuhinh.flow_from_directory('/content/drive/MyDrive/monan/monanVN/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 564 images belonging to 10 classes.

# %%
validation_data=kieuhinh.flow_from_directory('/content/drive/MyDrive/monan/monanVN/validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 99 images belonging to 10 classes.

# %%
training_data.class_indices
# Out:
# {'banhchung': 0,
#  'banhdacua': 1,
#  'banhkhot': 2,
#  'banhmi': 3,
#  'cachienxu': 4,
#  'chaca': 5,
#  'goicuon': 6,
#  'nemchua': 7,
#  'thitkhotau': 8,
#  'xoigac': 9}

# %%
model=Sequential()
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 256 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 82944)             0
#
#  dense (Dense)               (None, 512)               42467840
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 43,618,378
# Trainable params: 43,618,378
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = SGD(lr=0.01,momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history=model.fit(training_data,epochs=50,batch_size=200,verbose=1, validation_data=validation_data, callbacks=[EarlyStopping(monitor='val_loss', patience=30)])
# Out:
# Epoch 1/50
# 18/18 [==============================] - 210s 11s/step - loss: 3.2236 - accuracy: 0.1170 - val_loss: 2.3169 - val_accuracy: 0.1010
# Epoch 2/50
# 18/18 [==============================] - 17s 943ms/step - loss: 2.2942 - accuracy: 0.1277 - val_loss: 2.2688 - val_accuracy: 0.0909
# Epoch 3/50
# 18/18 [==============================] - 17s 927ms/step - loss: 2.1691 - accuracy: 0.1667 - val_loss: 2.1881 - val_accuracy: 0.1414
# Epoch 4/50
# 18/18 [==============================] - 17s 956ms/step - loss: 2.0703 - accuracy: 0.2429 - val_loss: 2.2777 - val_accuracy: 0.1818
# Epoch 5/50
# 18/18 [==============================] - 17s 922ms/step - loss: 2.0701 - accuracy: 0.2589 - val_loss: 2.0943 - val_accuracy: 0.2020
# Epoch 6/50
# 18/18 [==============================] - 17s 931ms/step - loss: 2.0311 - accuracy: 0.2376 - val_loss: 2.0563 - val_accuracy: 0.2323
# Epoch 7/50
# 18/18 [==============================] - 17s 940ms/step - loss: 2.0357 - accuracy: 0.2216 - val_loss: 2.0691 - val_accuracy: 0.2626
# Epoch 8/50
# 18/18 [==============================] - 17s 927ms/step - loss: 1.9058 - accuracy: 0.3067 - val_loss: 2.0629 - val_accuracy: 0.1919
# Epoch 9/50
# 18/18 [==============================] - 17s 935ms/step - loss: 1.8500 - accuracy: 0.3298 - val_loss: 1.8872 - val_accuracy: 0.3636
# Epoch 10/50
# 18/18 [==============================] - 17s 926ms/step - loss: 1.8021 - accuracy: 0.3298 - val_loss: 2.2269 - val_accuracy: 0.1616
# Epoch 11/50
# 18/18 [==============================] - 17s 925ms/step - loss: 1.7045 - accuracy: 0.3848 - val_loss: 1.8549 - val_accuracy: 0.3434
# Epoch 12/50
# 18/18 [==============================] - 17s 932ms/step - loss: 1.6508 - accuracy: 0.3954 - val_loss: 2.0741 - val_accuracy: 0.2626
# Epoch 13/50
# 18/18 [==============================] - 17s 937ms/step - loss: 1.6305 - accuracy: 0.4238 - val_loss: 2.0327 - val_accuracy: 0.3131
# Epoch 14/50
# 18/18 [==============================] - 17s 941ms/step - loss: 1.8067 - accuracy: 0.3777 - val_loss: 2.0768 - val_accuracy: 0.2626
# Epoch 15/50
# 18/18 [==============================] - 17s 940ms/step - loss: 1.7866 - accuracy: 0.3688 - val_loss: 1.9495 - val_accuracy: 0.2828
# Epoch 16/50
# 18/18 [==============================] - 17s 935ms/step - loss: 1.5884 - accuracy: 0.4344 - val_loss: 1.8454 - val_accuracy: 0.4242
# Epoch 17/50
# 18/18 [==============================] - 17s 940ms/step - loss: 1.2821 - accuracy: 0.5496 - val_loss: 1.5785 - val_accuracy: 0.4747
# Epoch 18/50
# 18/18 [==============================] - 17s 954ms/step - loss: 1.4059 - accuracy: 0.5124 - val_loss: 2.1302 - val_accuracy: 0.2424
# Epoch 19/50
# 18/18 [==============================] - 17s 944ms/step - loss: 1.3668 - accuracy: 0.5266 - val_loss: 1.8715 - val_accuracy: 0.4949
# Epoch 20/50
# 18/18 [==============================] - 17s 949ms/step - loss: 1.2608 - accuracy: 0.5727 - val_loss: 1.8362 - val_accuracy: 0.4343
# Epoch 21/50
# 18/18 [==============================] - 17s 935ms/step - loss: 1.2641 - accuracy: 0.5762 - val_loss: 1.8819 - val_accuracy: 0.3737
# Epoch 22/50
# 18/18 [==============================] - 17s 940ms/step - loss: 1.3439 - accuracy: 0.5567 - val_loss: 1.7588 - val_accuracy: 0.3535
# Epoch 23/50
# 18/18 [==============================] - 17s 935ms/step - loss: 1.1706 - accuracy: 0.5904 - val_loss: 1.9740 - val_accuracy: 0.2929
# Epoch 24/50
# 18/18 [==============================] - 17s 919ms/step - loss: 1.2407 - accuracy: 0.5585 - val_loss: 1.7988 - val_accuracy: 0.4646
# Epoch 25/50
# 18/18 [==============================] - 17s 906ms/step - loss: 1.0514 - accuracy: 0.6489 - val_loss: 2.0821 - val_accuracy: 0.4141
# Epoch 26/50
# 18/18 [==============================] - 17s 926ms/step - loss: 0.8255 - accuracy: 0.7216 - val_loss: 2.1206 - val_accuracy: 0.4343
# Epoch 27/50
# 18/18 [==============================] - 17s 937ms/step - loss: 0.9373 - accuracy: 0.6862 - val_loss: 2.2040 - val_accuracy: 0.3737
# Epoch 28/50
# 18/18 [==============================] - 17s 932ms/step - loss: 0.8919 - accuracy: 0.6826 - val_loss: 2.1766 - val_accuracy: 0.4040
# Epoch 29/50
# 18/18 [==============================] - 17s 938ms/step - loss: 0.8212 - accuracy: 0.7216 - val_loss: 1.9400 - val_accuracy: 0.3737
# Epoch 30/50
# 18/18 [==============================] - 17s 929ms/step - loss: 0.7265 - accuracy: 0.7571 - val_loss: 1.8620 - val_accuracy: 0.4949
# Epoch 31/50
# 18/18 [==============================] - 17s 920ms/step - loss: 0.5833 - accuracy: 0.8085 - val_loss: 2.0726 - val_accuracy: 0.4848
# Epoch 32/50
# 18/18 [==============================] - 17s 947ms/step - loss: 0.5932 - accuracy: 0.8014 - val_loss: 2.1409 - val_accuracy: 0.5152
# Epoch 33/50
# 18/18 [==============================] - 17s 925ms/step - loss: 0.6136 - accuracy: 0.8209 - val_loss: 2.2822 - val_accuracy: 0.4343
# Epoch 34/50
# 18/18 [==============================] - 17s 955ms/step - loss: 0.5279 - accuracy: 0.8280 - val_loss: 2.3431 - val_accuracy: 0.4848
# Epoch 35/50
# 18/18 [==============================] - 17s 942ms/step - loss: 0.3975 - accuracy: 0.8635 - val_loss: 2.8108 - val_accuracy: 0.4343
# Epoch 36/50
# 18/18 [==============================] - 17s 933ms/step - loss: 0.3923 - accuracy: 0.8688 - val_loss: 2.2982 - val_accuracy: 0.4848
# Epoch 37/50
# 18/18 [==============================] - 17s 950ms/step - loss: 0.2960 - accuracy: 0.9025 - val_loss: 2.3472 - val_accuracy: 0.5354
# Epoch 38/50
# 18/18 [==============================] - 17s 941ms/step - loss: 0.4081 - accuracy: 0.8723 - val_loss: 1.9708 - val_accuracy: 0.5051
# Epoch 39/50
# 18/18 [==============================] - 17s 946ms/step - loss: 0.3568 - accuracy: 0.8989 - val_loss: 2.0965 - val_accuracy: 0.5051
# Epoch 40/50
# 18/18 [==============================] - 17s 940ms/step - loss: 0.3151 - accuracy: 0.9007 - val_loss: 2.9223 - val_accuracy: 0.3939
# Epoch 41/50
# 18/18 [==============================] - 17s 920ms/step - loss: 0.3784 - accuracy: 0.8954 - val_loss: 2.0720 - val_accuracy: 0.4646
# Epoch 42/50
# 18/18 [==============================] - 17s 919ms/step - loss: 0.3287 - accuracy: 0.8936 - val_loss: 3.4538 - val_accuracy: 0.4949
# Epoch 43/50
# 18/18 [==============================] - 17s 946ms/step - loss: 0.6846 - accuracy: 0.8121 - val_loss: 2.2202 - val_accuracy: 0.4242
# Epoch 44/50
# 18/18 [==============================] - 17s 930ms/step - loss: 0.3450 - accuracy: 0.9007 - val_loss: 2.8902 - val_accuracy: 0.4646
# Epoch 45/50
# 18/18 [==============================] - 17s 913ms/step - loss: 0.3188 - accuracy: 0.8954 - val_loss: 3.4294 - val_accuracy: 0.4545
# Epoch 46/50
# 18/18 [==============================] - 17s 938ms/step - loss: 0.5004 - accuracy: 0.8528 - val_loss: 1.8905 - val_accuracy: 0.5152
# Epoch 47/50
# 18/18 [==============================] - 17s 959ms/step - loss: 0.2644 - accuracy: 0.9149 - val_loss: 2.6233 - val_accuracy: 0.5152

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
model.save("Nhan_dien_thuc_an.h5")

# %%
model_nhandien=load_model('Nhan_dien_thuc_an.h5')

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/xoigac.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# xoigac

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/banhchung.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# banhchung

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/nemchua.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# nemchua

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/goicuon.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# goicuon

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/chaca.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# goicuon

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/cachienxu.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# cachienxu

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/banhmi.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# banhmi

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/banhkhot.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# banhkhot

# %%
img=load_img("/content/drive/MyDrive/monan/monanVN/test/banhdacua.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='banhchung'
if round(result[0][1])==1:
  prediction='banhdacua'
if round(result[0][2])==1:
  prediction='banhkhot'
if round(result[0][3])==1:
  prediction='banhmi'
if round(result[0][4])==1:
  prediction='cachienxu'
if round(result[0][5])==1:
  prediction='chaca'
if round(result[0][6])==1:
  prediction='goicuon'
if round(result[0][7])==1:
  prediction='nemchua'
if round(result[0][8])==1:
  prediction='thitkhotau'
if round(result[0][9])==1:
  prediction='xoigac'
print(prediction)
# Out:
# banhdacua
