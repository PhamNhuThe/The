# %%
from keras.models import Sequential
from keras.layers import Convolution2D as Conv2D
from keras.layers import Flatten, MaxPooling2D
from keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
from keras.layers import Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
batch_size = 1
img_size = (150, 150)
img_path = '/content/drive/MyDrive/ronaldo/train'

# %%
image_generator = ImageDataGenerator(
    rescale = 1./255,
    brightness_range = (0.8, 1.2),
    zoom_range= (0.9, 1.2),
    validation_split= 0.2)

train_dataset= image_generator.flow_from_directory(img_path,
                                      target_size = img_size,
                                      batch_size = batch_size,
                                      shuffle = True,
                                      class_mode = 'categorical',
                                      subset = 'training')
validation_dataset = image_generator.flow_from_directory(img_path,
                                      target_size = img_size,
                                      batch_size = batch_size,  
                                      shuffle = True,
                                      class_mode = 'categorical',
                                      subset = 'validation')
# Out:
# Found 19 images belonging to 2 classes.
# Found 3 images belonging to 2 classes.

# %%
train_dataset.classes
print(train_dataset.class_indices)
# Out:
# {'Me': 0, 'Ronaldo': 1}

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(512, kernel_size = (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(2,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 74, 74, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 36, 36, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 17, 17, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 7, 7, 256)        1024
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 512)         1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 1,833,026
# Trainable params: 1,832,066
# Non-trainable params: 960
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model.compile(optimizer = opt, loss ='binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(train_dataset,batch_size=65,epochs=20,validation_data=validation_dataset)
# Out:
# Epoch 1/20
# 19/19 [==============================] - 16s 783ms/step - loss: 0.4608 - accuracy: 0.7368 - val_loss: 0.7608 - val_accuracy: 0.3333
# Epoch 2/20
# 19/19 [==============================] - 5s 231ms/step - loss: 0.0477 - accuracy: 1.0000 - val_loss: 0.9181 - val_accuracy: 0.3333
# Epoch 3/20
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0519 - val_accuracy: 0.3333
# Epoch 4/20
# 19/19 [==============================] - 3s 184ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1616 - val_accuracy: 0.3333
# Epoch 5/20
# 19/19 [==============================] - 5s 243ms/step - loss: 4.8712e-04 - accuracy: 1.0000 - val_loss: 1.1951 - val_accuracy: 0.3333
# Epoch 6/20
# 19/19 [==============================] - 4s 204ms/step - loss: 5.6744e-04 - accuracy: 1.0000 - val_loss: 1.2851 - val_accuracy: 0.3333
# Epoch 7/20
# 19/19 [==============================] - 3s 166ms/step - loss: 7.2418e-04 - accuracy: 1.0000 - val_loss: 1.3007 - val_accuracy: 0.3333
# Epoch 8/20
# 19/19 [==============================] - 3s 160ms/step - loss: 4.2401e-04 - accuracy: 1.0000 - val_loss: 1.3902 - val_accuracy: 0.3333
# Epoch 9/20
# 19/19 [==============================] - 3s 157ms/step - loss: 3.0723e-04 - accuracy: 1.0000 - val_loss: 1.4037 - val_accuracy: 0.3333
# Epoch 10/20
# 19/19 [==============================] - 3s 162ms/step - loss: 4.1894e-04 - accuracy: 1.0000 - val_loss: 1.5131 - val_accuracy: 0.3333
# Epoch 11/20
# 19/19 [==============================] - 3s 158ms/step - loss: 9.3579e-04 - accuracy: 1.0000 - val_loss: 1.0193 - val_accuracy: 0.3333
# Epoch 12/20
# 19/19 [==============================] - 3s 159ms/step - loss: 3.4522e-04 - accuracy: 1.0000 - val_loss: 0.8445 - val_accuracy: 0.3333
# Epoch 13/20
# 19/19 [==============================] - 3s 160ms/step - loss: 4.4717e-04 - accuracy: 1.0000 - val_loss: 0.8753 - val_accuracy: 0.3333
# Epoch 14/20
# 19/19 [==============================] - 3s 157ms/step - loss: 4.3749e-04 - accuracy: 1.0000 - val_loss: 0.6310 - val_accuracy: 0.3333
# Epoch 15/20
# 19/19 [==============================] - 3s 157ms/step - loss: 5.7856e-04 - accuracy: 1.0000 - val_loss: 0.9246 - val_accuracy: 0.3333
# Epoch 16/20
# 19/19 [==============================] - 3s 156ms/step - loss: 2.5989e-04 - accuracy: 1.0000 - val_loss: 0.3606 - val_accuracy: 1.0000
# Epoch 17/20
# 19/19 [==============================] - 3s 162ms/step - loss: 3.7803e-04 - accuracy: 1.0000 - val_loss: 0.2813 - val_accuracy: 1.0000
# Epoch 18/20
# 19/19 [==============================] - 3s 160ms/step - loss: 4.4312e-04 - accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 1.0000
# Epoch 19/20
# 19/19 [==============================] - 3s 153ms/step - loss: 2.8289e-04 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 1.0000
# Epoch 20/20
# 19/19 [==============================] - 3s 154ms/step - loss: 3.2726e-04 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 1.0000

# %%
validation_dataset.labels
# Out:
# array([0, 0, 1], dtype=int32)

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

filename = "/content/drive/MyDrive/ronaldo/test/Me/2022_05_25_06_58_IMG_3689.JPG"

img = load_img(filename,target_size= img_size)
plt.imshow(img)
plt.show

img = img_to_array(img)
img  = img.reshape(1,*img_size,3)
img = img.astype('float32')
img = img/255
test = np.argmax(model.predict(img),axis =1)
if(test ==1):
    print("Ronaldo")
if(test==0):
    print("Pham Nhu The")
# Out:
# Pham Nhu The

# %%
filename = "/content/drive/MyDrive/ronaldo/test/Ronaldo/cristiano-ronaldo-t4894.jpg"

img = load_img(filename,target_size= img_size)
plt.imshow(img)
plt.show

img = img_to_array(img)
img  = img.reshape(1,*img_size,3)
img = img.astype('float32')
img = img/255
test = np.argmax(model.predict(img),axis =1)
if(test ==1):
    print("Ronaldo")
if(test==0):
    print("Pham Nhu The")
# Out:
# Ronaldo
